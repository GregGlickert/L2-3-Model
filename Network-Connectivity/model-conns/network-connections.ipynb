# %%
from bmtool import bmplot as bp

bp.convergence_connection_matrix(config="../../Network-Parameters/config_baseline.json",sources='cortex',targets='cortex',sids='pop_name',tids='pop_name',no_prepend_pop=True)

# %%
bp.percent_connection_matrix(config="../../Network-Parameters/config_baseline.json",sources='cortex',targets='cortex',sids='pop_name',tids='pop_name',no_prepend_pop=True)

# %%
bp.convergence_connection_matrix(config="../../Network-Parameters/config_baseline.json",sources='shell',targets='cortex',sids='pop_name',tids='pop_name',no_prepend_pop=True)

# %%
bp.convergence_connection_matrix(config="../../Network-Parameters/config_baseline.json",sources='thalamus',targets='cortex',sids='pop_name',tids='pop_name',no_prepend_pop=True)

# %%
bp.convergence_connection_matrix(config="../../Network-Parameters/config_baseline.json",sources='baseline',targets='cortex',sids='pop_name',tids='pop_name',no_prepend_pop=True)
